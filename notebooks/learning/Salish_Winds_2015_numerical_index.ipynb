# %% [markdown]
# # Plotting winds >7 m/s for each month in atmospheric forcing files

# %%
import xarray as xr
import matplotlib.pyplot as plt
import math
import numpy as np
import arrow
import cmocean

# %%
# %matplotlib inline

# %%
ds = xr.open_dataset('https://salishsea.eos.ubc.ca/erddap/griddap/ubcSSaSurfaceAtmosphereFieldsV1')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (gridX: 256, gridY: 266, time: 36456)
# Coordinates:
#   * time       (time) datetime64[ns] 2014-09-12 ... 2018-11-08T23:00:00
#   * gridY      (gridY) float64 0.0 2.5e+03 5e+03 ... 6.575e+05 6.6e+05 6.625e+05
#   * gridX      (gridX) float64 0.0 2.5e+03 5e+03 ... 6.35e+05 6.375e+05
# Data variables:
#     atmpres    (time, gridY, gridX) float32 ...
#     precip     (time, gridY, gridX) float32 ...
#     qair       (time, gridY, gridX) float32 ...
#     solar      (time, gridY, gridX) float32 ...
#     tair       (time, gridY, gridX) float32 ...
#     therm_rad  (time, gridY, gridX) float32 ...
#     u_wind     (time, gridY, gridX) float32 ...
#     v_wind     (time, gridY, gridX) float32 ...
# Attributes:
#     acknowledgement:           MEOPAR, ONC, Compute Canada, Environment Canada
#     cdm_data_type:             Grid
#     Conventions:               CF-1.6, COARDS, ACDD-1.3
#     coverage_content_type:     modelResult
#     creator_email:             sallen@eos.ubc.ca
#     creator_name:              Salish Sea MEOPAR Project Contributors
#     creator_url:               https://salishsea-meopar-docs.readthedocs.io/
#     drawLandMask:              over
#     GRIB2_grid_template:       20
#     history:                   Thu Mar 10 10:11:37 2016: ncks -4 -L4 -O /resu...
#     infoUrl:                   https://salishsea-meopar-docs.readthedocs.io/e...
#     institution:               UBC EOAS
#     institution_fullname:      Earth, Ocean & Atmospheric Sciences, Universit...
#     keywords:                  atmosphere, atmospheric, atmpres, Earth Scienc...
#     keywords_vocabulary:       GCMD Science Keywords
#     license:                   The Salish Sea MEOPAR NEMO model results are c...
#     NCO:                       4.4.2
#     project:                   Salish Sea MEOPAR NEMO Model
#     sourceUrl:                 (local files)
#     standard_name_vocabulary:  CF Standard Name Table v29
#     summary:                   HRDPS, Salish Sea, Atmospheric Forcing Fields,...
#     testOutOfDate:             now-12hours
#     time_coverage_end:         2018-11-08T23:00:00Z
#     time_coverage_start:       2014-09-12T00:00:00Z
#     title:                     HRDPS, Salish Sea, Atmospheric Forcing Fields,...

# %%
ds.time[0]
# Out:
# <xarray.DataArray 'time' ()>
# array(1410480000000000000, dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 2014-09-12
# Attributes:
#     _ChunkSizes:                 1
#     _CoordinateAxisType:         Time
#     actual_range:                [  1.41048000e+09   1.54171800e+09]
#     axis:                        T
#     ioos_category:               Time
#     long_name:                   verification time generated by wgrib2 functi...
#     reference_date:              2018.11.07 18:00:00 UTC
#     reference_time:              1541613600.0
#     reference_time_description:  kind of product unclear, reference date is v...
#     reference_time_type:         0
#     standard_name:               time
#     time_origin:                 01-JAN-1970 00:00:00
#     time_step:                   3600.0
#     time_step_setting:           auto

# %%
ds.time[-1]
# Out:
# <xarray.DataArray 'time' ()>
# array(1541718000000000000, dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 2018-11-08T23:00:00
# Attributes:
#     _ChunkSizes:                 1
#     _CoordinateAxisType:         Time
#     actual_range:                [  1.41048000e+09   1.54171800e+09]
#     axis:                        T
#     ioos_category:               Time
#     long_name:                   verification time generated by wgrib2 functi...
#     reference_date:              2018.11.07 18:00:00 UTC
#     reference_time:              1541613600.0
#     reference_time_description:  kind of product unclear, reference date is v...
#     reference_time_type:         0
#     standard_name:               time
#     time_origin:                 01-JAN-1970 00:00:00
#     time_step:                   3600.0
#     time_step_setting:           auto

# %% [markdown]
# ## Slice JFM time and then converts xarray into numpy array using ".values"

# %%
jan2015_time = ds.time.sel(time=slice("2015-01-01","2015-01-31")).values
jan2015_wspd = np.sqrt(ds.u_wind.sel(time = jan2015_time)**2 + ds.v_wind.sel(time = jan2015_time)**2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in _getitem(self, key)
#      68             try:
# ---> 69                 array = getitem(self.get_array(), key)
#      70             except IndexError:
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/backends/common.py in robust_getitem(array, key, catch, max_retries, initial_delay)
#     122         try:
# --> 123             return array[key]
#     124         except catch:
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable.__getitem__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable._get()
#
# IndexError: index exceeds dimension bounds
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-c699eb5c5dfa> in <module>()
#       1 jan2015_time = ds.time.sel(time=slice("2015-01-01","2015-01-31")).values
# ----> 2 jan2015_wspd = np.sqrt(ds.u_wind.sel(time = jan2015_time)**2 + ds.v_wind.sel(time = jan2015_time)**2)
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/dataarray.py in func(self, other)
#    1964
#    1965             variable = (f(self.variable, other_variable)
# -> 1966                         if not reflexive
#    1967                         else f(other_variable, self.variable))
#    1968             coords = self.coords._merge_raw(other_coords)
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/variable.py in func(self, other)
#    1653             if isinstance(other, (xr.DataArray, xr.Dataset)):
#    1654                 return NotImplemented
# -> 1655             self_data, other_data, dims = _broadcast_compat_data(self, other)
#    1656             with np.errstate(all='ignore'):
#    1657                 new_data = (f(self_data, other_data)
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/variable.py in _broadcast_compat_data(self, other)
#    1924     else:
#    1925         # rely on numpy broadcasting rules
# -> 1926         self_data = self.data
#    1927         other_data = other
#    1928         dims = self.dims
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/variable.py in data(self)
#     289             return self._data
#     290         else:
# --> 291             return self.values
#     292
#     293     @data.setter
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/variable.py in values(self)
#     381     def values(self):
#     382         """The variable's data as a numpy.ndarray"""
# --> 383         return _as_array_or_item(self._data)
#     384
#     385     @values.setter
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/variable.py in _as_array_or_item(data)
#     205     TODO: remove this (replace with np.asarray) once these issues are fixed
#     206     """
# --> 207     data = np.asarray(data)
#     208     if data.ndim == 0:
#     209         if data.dtype.kind == 'M':
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     622
#     623     def __array__(self, dtype=None):
# --> 624         self._ensure_cached()
#     625         return np.asarray(self.array, dtype=dtype)
#     626
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/indexing.py in _ensure_cached(self)
#     619     def _ensure_cached(self):
#     620         if not isinstance(self.array, NumpyIndexingAdapter):
# --> 621             self.array = NumpyIndexingAdapter(np.asarray(self.array))
#     622
#     623     def __array__(self, dtype=None):
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     600
#     601     def __array__(self, dtype=None):
# --> 602         return np.asarray(self.array, dtype=dtype)
#     603
#     604     def __getitem__(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     506     def __array__(self, dtype=None):
#     507         array = as_indexable(self.array)
# --> 508         return np.asarray(array[self.key], dtype=None)
#     509
#     510     def transpose(self, order):
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/coding/variables.py in __array__(self, dtype)
#      67
#      68     def __array__(self, dtype=None):
# ---> 69         return self.func(self.array)
#      70
#      71     def __repr__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/coding/variables.py in _apply_mask(data, encoded_fill_values, decoded_fill_value, dtype)
#     133                 ):  # type: np.ndarray
#     134     """Mask all matching values in a NumPy arrays."""
# --> 135     data = np.asarray(data, dtype=dtype)
#     136     condition = False
#     137     for fv in encoded_fill_values:
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     506     def __array__(self, dtype=None):
#     507         array = as_indexable(self.array)
# --> 508         return np.asarray(array[self.key], dtype=None)
#     509
#     510     def transpose(self, order):
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in __getitem__(self, key)
#      57         return indexing.explicit_indexing_adapter(
#      58             key, self.shape, indexing.IndexingSupport.OUTER,
# ---> 59             self._getitem)
#      60
#      61     def _getitem(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/core/indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     774     """
#     775     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 776     result = raw_indexing_method(raw_key.tuple)
#     777     if numpy_indices.tuple:
#     778         # index the loaded np.ndarray
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in _getitem(self, key)
#      78                     import traceback
#      79                     msg += '\n\nOriginal traceback:\n' + traceback.format_exc()
# ---> 80                 raise IndexError(msg)
#      81         return array
#      82
#
# IndexError: The indexing operation you are attempting to perform is not valid on netCDF4.Variable object. Try loading your data into memory first by calling .load().

# %%
len(jan2015_time)

# %%
len(ds.time)

# %%
u = ds.u_wind.sel(time=slice("2015-01-01","2015-01-31"))

# %%
u = ds.u_wind.sel(time = jan2015_time)
v = ds.v_wind.sel(time = jan2015_time)

# %%
len(u)

# %%
u

# %%
# Trying to debug what is going on....
#u = ds.u_wind.sel(time = "2015-01-01").values
#v = ds.v_wind.sel(time = "2015-01-01").values

# %% [markdown]
# ## Calculate percent time that january 2015 wind speeds are > 7 m/s

# %%
# extract january winds and calculate wind speed from u-, v-components
# The below code worked...and then didn't?!?!?! commenting out to try alternative method
jan2015_wspd = np.sqrt(ds.u_wind.sel(time = jan2015_time)**2 + ds.v_wind.sel(time = jan2015_time)**2)

# %%
# Trying to debug what is going on....
#jan2015_wspd = np.sqrt(u**2 + v**2)

# %%
# 
thresh = 7
wspd_size = jan2015_wspd.shape
total = wspd_size[0]

# %%
# Create numpy array for percentage value output
wspd_2D_percent = np.zeros((wspd_size[1],wspd_size[2]))
for iy in range(0,wspd_size[1]):
    for ix in range(0,wspd_size[2]):
        wspd_ts = jan2015_wspd[:,iy,ix]
        wspd_ts_thresh =  wspd_ts[wspd_ts > thresh]
        wspd_2D_percent[iy,ix] = 100 * len(wspd_ts_thresh) / total

# %%
total

# %%
wspd_size

# %% [markdown]
# ## plot up results

# %%
fig, ax = plt.subplots()
cax = ax.imshow(np.flipud(wspd_2D_percent))
ax.set_title('Percent time with wind speed over 10 m/s for Jan. 2015')
cbar = fig.colorbar(cax, orientation='vertical')
cbar.ax.set_ylabel('%')

# %% [markdown]
# ## now repeat for all months and plot them together

# %%
time_15_01 = ds.time.sel(time=slice("2015-01-01","2015-01-31")).values
time_15_02 = ds.time.sel(time=slice("2015-02-01","2015-02-28")).values
time_15_03 = ds.time.sel(time=slice("2015-03-01","2015-03-31")).values
time_15_04 = ds.time.sel(time=slice("2015-04-01","2015-04-30")).values
time_15_05 = ds.time.sel(time=slice("2015-05-01","2015-05-31")).values
time_15_06 = ds.time.sel(time=slice("2015-06-01","2015-06-30")).values
time_15_07 = ds.time.sel(time=slice("2015-07-01","2015-07-31")).values
time_15_08 = ds.time.sel(time=slice("2015-08-01","2015-08-31")).values
time_15_10 = ds.time.sel(time=slice("2015-09-01","2015-09-30")).values
time_15_10 = ds.time.sel(time=slice("2015-10-01","2015-10-31")).values
time_15_11 = ds.time.sel(time=slice("2015-11-01","2015-11-30")).values
time_15_12 = ds.time.sel(time=slice("2015-12-01","2015-12-31")).values
