# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cmocean
# %matplotlib inline

# %%
dxr = xr.open_dataset('https://salishsea.eos.ubc.ca/erddap/griddap/ubcSSgSurfaceTracerFields1hV18-06')

# %%
dxr
# Out:
# <xarray.Dataset>
# Dimensions:  (gridX: 398, gridY: 898, time: 36696)
# Coordinates:
#   * time     (time) datetime64[ns] 2014-11-13T00:30:00 ... 2019-01-20T23:30:00
#   * gridY    (gridY) int16 0 1 2 3 4 5 6 7 8 ... 890 891 892 893 894 895 896 897
#   * gridX    (gridX) int16 0 1 2 3 4 5 6 7 8 ... 390 391 392 393 394 395 396 397
# Data variables:
#     ssh      (time, gridY, gridX) float32 ...
# Attributes:
#     acknowledgement:           MEOPAR, ONC, Compute Canada
#     cdm_data_type:             Grid
#     Conventions:               CF-1.6, COARDS, ACDD-1.3
#     creator_email:             sallen@eoas.ubc.ca
#     creator_name:              Salish Sea MEOPAR Project Contributors
#     creator_url:               https://salishsea-meopar-docs.readthedocs.io/
#     description:               ocean surface T grid variables
#     drawLandMask:              over
#     history:                   2019-01-20T22:21:26Z (local files)\n2019-01-20...
#     infoUrl:                   https://salishsea-meopar-docs.readthedocs.io/e...
#     institution:               UBC EOAS
#     institution_fullname:      Earth, Ocean & Atmospheric Sciences, Universit...
#     keywords:                  deptht, Earth Science > Oceans > Ocean Circula...
#     license:                   The Salish Sea MEOPAR NEMO model results are c...
#     project:                   Salish Sea MEOPAR NEMO Model
#     sourceUrl:                 (local files)
#     standard_name_vocabulary:  CF Standard Name Table v29
#     summary:                   Green, Salish Sea, Surface Tracer Fields, Hour...
#     testOutOfDate:             now-16hours
#     time_coverage_end:         2019-01-20T23:30:00Z
#     time_coverage_start:       2014-11-13T00:30:00Z
#     timeStamp:                 2019-Jan-20 17:30:37 GMT
#     title:                     Green, Salish Sea, Surface Tracer Fields, Hour...
#     uuid:                      ec6cc8a2-0726-4057-a135-9d1a8c0fed23

# %%
ssh = dxr.ssh[24*30:24*60,520,230]
ssh
# Out:
# <xarray.DataArray 'ssh' (time: 720)>
# array([-0.077493, -0.211392, -0.200345, ...,  0.334431, -0.122916, -0.514128], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 2014-12-14T00:30:00 ... 2015-01-12T23:30:00
#     gridY    int16 520
#     gridX    int16 230
# Attributes:
#     _ChunkSizes:            [  1 898 398]
#     colorBarMaximum:        4.0
#     colorBarMinimum:        -4.0
#     coverage_content_type:  modelResult
#     ioos_category:          sea_level
#     long_name:              sea surface height
#     standard_name:          sea_surface_height_above_geoid
#     units:                  m

# %%
ssh.plot()
